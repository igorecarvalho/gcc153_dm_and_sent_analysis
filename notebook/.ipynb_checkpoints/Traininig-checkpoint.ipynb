# %%
from nltk import word_tokenize
import nltk
import re
import pandas as pd
# Out:
# /usr/lib/python3.7/site-packages/sklearn/feature_extraction/text.py:17: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Mapping, defaultdict

# %% [markdown]
# # OBTENÇÃO DOS DADOS

# %%
dataset = pd.read_csv('../data/.csv', encoding='UTF-8')
del dataset['Geo Coordinates.latitude']
del dataset['Geo Coordinates.longitude']
del dataset['Created At']
del dataset['Unnamed: 0']
del dataset['User Location']
del dataset['User Screen Name']
del dataset['Username']
del dataset['Retweet Count']
del dataset['Observação']
del dataset['Unnamed: 10']
del dataset['Unnamed: 11']
del dataset['Unnamed: 12']
del dataset['Unnamed: 13']
del dataset['Unnamed: 14']
del dataset['Unnamed: 15']
del dataset['Unnamed: 16']
del dataset['Unnamed: 17']
del dataset['Unnamed: 18']
del dataset['Unnamed: 19']
del dataset['Unnamed: 20']
del dataset['Unnamed: 21']
del dataset['Unnamed: 22']
del dataset['Unnamed: 23']
del dataset['Unnamed: 24']
dataset[:5]
# Out:
#                                                 Text Classificacao
# 0  ���⛪ @ Catedral de Santo Antônio - Governador ...        Neutro
# 1  � @ Governador Valadares, Minas Gerais https:/...        Neutro
# 2  �� @ Governador Valadares, Minas Gerais https:...        Neutro
# 3                        ��� https://t.co/BnDsO34qK0        Neutro
# 4  ��� PSOL vai questionar aumento de vereadores ...      Negativo

# %%
depurate_tweets = pd.read_pickle('../data/depurate_tweets.pkl')
depurate_tweets[:5]
# Out:
#          date                                               news polarity_new  \
# 0  2019-10-01  [[PF emite certidão à Justiça para dizer que L...         None
# 1  2019-10-02  [[Para Maia, derrota em abono não significa pe...         None
# 2  2019-10-03  [[Flávia Boggio | Acho impossível esconder a i...         None
# 3  2019-10-04  [[Camargo processa ex-executivo por desvio mil...         None
# 4  2019-10-05  [[Desde janeiro, o jornal tem uma editoria de ...         None
#
#             news_keywords                                             tweets  \
# 0            (lava, jato)  1399    Lava Jato cobra multa de R$ 5 milhões ...
# 1  (reforma, previdência)  1398    Economia com reforma da Previdência de...
# 2     (pacote, anticrime)  1399    Governo Federal lança campanha publici...
# 3            (lava, jato)  1399    # BRASIL: Los fiscales justicieros del...
# 4  (conselhos, tutelares)  1399    Invasão da Universal ameaça aparelhar ...
#
#                                    normalized_tweets polarity_tweets
# 0  1399    [lava, jato, cobra, multa, de, r, 5, m...            None
# 1  1398    [economia, com, reforma, da, previdênc...            None
# 2  1399    [governo, federal, lança, campanha, pu...            None
# 3  1399    [brasil, los, fiscales, justicieros, d...            None
# 4  1399    [invasão, da, universal, ameaça, apare...            None

# %%
dataset.drop_duplicates(['Text'], inplace=True)
tweets = dataset['Text']
classes = dataset['Classificacao']

# %%
# %matplotlib inline
dataset.Classificacao.value_counts().plot(kind='bar')

# %% [markdown]
# # PREPROCESSAMENTO DOS TWEETS CLASSIFICADOS

# %%
import nltk
nltk.download('stopwords')
nltk.download('rslp')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/igorecarvalho/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package rslp to
# [nltk_data]     /home/igorecarvalho/nltk_data...
# [nltk_data]   Package rslp is already up-to-date!
# True

# %%
def Preprocessing(instancia):
    stemmer = nltk.stem.RSLPStemmer()
    instancia = re.sub(r"http\S+", "", instancia).lower().replace('.','').replace(';','').replace('-','').replace(':','').replace(')','')
    stopwords = set(nltk.corpus.stopwords.words('portuguese'))
    palavras = [stemmer.stem(i) for i in instancia.split() if not i in stopwords]
    return (" ".join(palavras))

# Aplica a função em todos os dados:
tweets = [Preprocessing(i) for i in tweets]

# %% [markdown]
# # TREINANDO O MODELO

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
from sklearn.model_selection import cross_val_predict

# %%
vectorizer = CountVectorizer(analyzer="word")
freq_tweets = vectorizer.fit_transform(tweets)
modelo = MultinomialNB()
modelo.fit(freq_tweets,classes)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
from sklearn.pipeline import Pipeline
pipeline_simples = Pipeline([
  ('counts', CountVectorizer()),
  ('classifier', MultinomialNB())
])

# %%
pipeline_simples.fit(tweets,classes)
pipeline_simples.steps
# Out:
# [('counts',
#   CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#           dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#           lowercase=True, max_df=1.0, max_features=None, min_df=1,
#           ngram_range=(1, 1), preprocessor=None, stop_words=None,
#           strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#           tokenizer=None, vocabulary=None)),
#  ('classifier', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))]

# %% [markdown]
# # VALIDAÇÃO

# %%
resultados = cross_val_predict(pipeline_simples, tweets, classes, cv=10)
metrics.accuracy_score(classes,resultados)
# Out:
# 0.8631396357328708

# %%
sentimento=['Positivo','Negativo','Neutro']
print (metrics.classification_report(classes,resultados,sentimento))
print (pd.crosstab(classes, resultados, rownames=['Real'], colnames=['Predito'], margins=True))
# Out:
#              precision    recall  f1-score   support
#
#    Positivo       0.96      0.86      0.91      2840
#    Negativo       0.77      0.90      0.83       951
#      Neutro       0.80      0.85      0.82      1974
#
# avg / total       0.87      0.86      0.87      5765
#
# Predito   Negativo  Neutro  Positivo   All
# Real
# Negativo       852      91         8   951
# Neutro         196    1674       104  1974
# Positivo        64     326      2450  2840
# All           1112    2091      2562  5765

# %% [markdown]
# # TESTANDO O MODELO TREINADO

# %%
import itertools
#testes = list(itertools.chain.from_iterable(depurate_tweets['news'][13]))
testes = depurate_tweets['tweets'][28]
testes = [Preprocessing(i) for i in testes]
# Transforma os dados de teste em vetores de palavras.
freq_testes = vectorizer.transform(testes)
# Fazendo a classificação com o modelo treinado.
pd.DataFrame(modelo.predict(freq_testes)).describe()
# Out:
#              0
# count      554
# unique       3
# top     Neutro
# freq       480

# %%
# Probabilidades de cada classe
print (modelo.classes_)
modelo.predict_proba(freq_testes).round(2)
# Out:
# ['Negativo' 'Neutro' 'Positivo']
# array([[0.42, 0.26, 0.32],
#        [0.  , 1.  , 0.  ],
#        [0.31, 0.45, 0.24],
#        ...,
#        [0.01, 0.99, 0.  ],
#        [0.  , 1.  , 0.  ],
#        [0.  , 1.  , 0.  ]])

# %%
depurate_tweets['tweets'][15], modelo.predict(freq_testes)
# Out:
# (697    ESTÃO ABORRECIDOS?!?!?!?!? VCS AINDA NÃO VIRAM...
#  689    Um ministro digno no STF. chega de impunidade....
#  686    @ CNJ_oficial informa que foram expedidos 4.89...
#  683    Relatora dá parecer favorável à PEC que prevê ...
#  680    Ministros do STF defendem prisão após julgamen...
#  679    No documento, a Ajufe avalia que a PEC - favor...
#  677    Ministros do @ STF_oficial, em qual país um cr...
#  676    A CCJ da Câmara começou a analisar uma propost...
#  675    Luiz Fux diz que derrubar prisão após 2ª instâ...
#  674    CNJ diz que 4.895 presos podem ser beneficiado...
#  667    Toffoli informou que os ministros só vão começ...
#  666    CNJ: Julgamento de prisão após 2ª instância po...
#  665    Amanhã começa a enganação do STF pra cima do B...
#  663    Rodrigo Maia acabou de declarar que não dará p...
#  661    O ministro quer cumprir o que prometeu aos ban...
#  660    eu sobre a 2ª instância: STF não tem o privilé...
#  658    Julgamento de prisão após 2ª instância pode af...
#  657    # CCJDaCamara CAROLINE DE TONI Relatora dá par...
#  656    De véspera, ministros do STF defendem prisão e...
#  655    Mudar regra sobre prisão em 2ª instância é ret...
#  654    Alvo de disputa no Brasil, prisão após condena...
#  653    Por que não falam que esses 4.895 presos são a...
#  652    Mudar regra sobre prisão em 2ª instância é ret...
#  651    Barroso diz que stf tem que decidir sobre 2ª i...
#  647    Mudar regra sobre prisão em 2ª instância é ret...
#  646    Votos da ação sobre prisão após condenação em ...
#  645    Relatora apresenta parecer favorável à propost...
#  643    Relatora Caroline De Toni dá parecer favorável...
#  641    Lógico! Ele tem interesse em acabar com a pris...
#  639    # TodaForçaÀLavaJato Fux diz que derrubar pris...
#                               ...
#  44     No @ STF_oficial prisão em 2ª instância: Até 2...
#  43     Gilmar Mendes e Bolsonaro se reúnem na véspera...
#  42     No @ STF_oficial prisão em 2ª instância: Até 2...
#  41     2ª instância: Villas Boas tenta emparedar STF ...
#  39     No @ STF_oficial prisão em 2ª instância: Até 2...
#  38     No @ STF_oficial prisão em 2ª instância: Até 2...
#  36     Julgamento do STF de prisão após 2ª instância ...
#  34     A sociedade, que apoia maciçamente o fim da im...
#  33     Senadores reagem a julgamento da prisão em 2ª ...
#  32     Roendo a corda… Voto do relator sobre prisão a...
#  31     O Brasil consagrou o princípio da presunção da...
#  30     Toffoli diz que julgamento sobre prisão em 2ª ...
#  29     Julgamento sobre prisão em 2ª instância se est...
#  27     ISPIAAAAA O GOLPEEEEE. CANALHASSSS Na véspera ...
#  26     Meu unicórnio de estimação acredita que eles n...
#  25     Votos sobre prisão em 2ª instância só ocorrerã...
#  24     Votação do STF sobre prisão em 2ª instância nã...
#  23     Voto do relator sobre prisão após 2ª instância...
#  21     A OAB está tomando a frente contra a liberdade...
#  20     Perfeito: essa PEC e a posição do STF de 2016 ...
#  19     STF só votará prisão em 2ª instância na semana...
#  18     Vênus Platinada, também conhecida como GLOBO, ...
#  14     Mudar regra sobre prisão em 2ª instância é ret...
#  13     BARROSO do STF defendem prisão após julgamento...
#  12     Votação do STF sobre prisão em 2ª instância nã...
#  10     Na véspera do julgamento da 2ª instância no ST...
#  8      Ministros BARROSO E FUX (SÓ ELES?) do STF defe...
#  6      Ministros do STF defendem prisão após julgamen...
#  4      Maia quer aguardar STF para decidir se PEC sob...
#  1      Parece que STF não decidirá amanhã a prisão em...
#  Name: text, Length: 425, dtype: object,
#  array(['Negativo', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Negativo', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Negativo', 'Neutro', 'Neutro', 'Neutro',
#         'Negativo', 'Negativo', 'Neutro', 'Positivo', 'Neutro', 'Negativo',
#         'Negativo', 'Neutro', 'Neutro', 'Negativo', 'Negativo', 'Negativo',
#         'Neutro', 'Negativo', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Negativo', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Negativo', 'Negativo', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Negativo', 'Negativo', 'Negativo',
#         'Negativo', 'Neutro', 'Negativo', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Negativo', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Negativo', 'Negativo', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Negativo', 'Negativo', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Negativo',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Negativo',
#         'Neutro', 'Negativo', 'Negativo', 'Negativo', 'Neutro', 'Neutro',
#         'Negativo', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Negativo', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Negativo', 'Neutro', 'Negativo',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Negativo', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Negativo',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Negativo',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Negativo', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Negativo', 'Negativo', 'Negativo', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Negativo', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Negativo', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Negativo', 'Neutro', 'Negativo', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Negativo', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Negativo', 'Neutro',
#         'Neutro', 'Negativo', 'Neutro', 'Neutro', 'Negativo', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Negativo', 'Neutro', 'Neutro', 'Negativo',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Negativo', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Negativo',
#         'Neutro', 'Neutro', 'Neutro', 'Negativo', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Negativo', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Negativo', 'Neutro', 'Negativo', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Negativo', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Negativo', 'Neutro', 'Neutro',
#         'Neutro', 'Negativo', 'Negativo', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Negativo', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Negativo', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Negativo', 'Negativo',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Negativo',
#         'Neutro', 'Negativo', 'Negativo', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Negativo', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Negativo', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Negativo', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Negativo', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Negativo', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Negativo', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro', 'Neutro',
#         'Neutro', 'Neutro'], dtype='<U8'))

# %% [markdown]
# # TAGGEANDO OS DADOS

# %%
#remove linha com nenhum resultado
#14/10/19
depurate_tweets = depurate_tweets.drop([13])

# %%
import itertools
def labeling(tweets):
    #print(tweets)
    #testes = list(itertools.chain.from_iterable(depurate_tweets['news'][13]))
    #print(len(tweets))
    tweets = [Preprocessing(i) for i in tweets]
    freq_testes = vectorizer.transform(tweets)
    labeled_tweets = modelo.predict(freq_testes)
    #print(len(labeled_tweets))
    top_label = pd.DataFrame(labeled_tweets).describe()[0][2]
    #print(top_label)
    return len(labeled_tweets), top_label, labeled_tweets

# %%
top_label = []
for tweet_date in depurate_tweets['tweets']:
    #tweet_date = list(itertools.chain.from_iterable(tweet_date))
    #print(tweet_date)
    top_label.append(labeling(tweet_date))
depurate_tweets['polarity_tweets'] = top_label

# %%
top_label = []
for tweet_date in depurate_tweets['news']:
    tweet_date = list(itertools.chain.from_iterable(tweet_date))
    #print(tweet_date)
    top_label.append(labeling(tweet_date))
depurate_tweets['polarity_new'] = top_label

# %%
depurate_tweets
# Out:
#           date                                               news  \
# 0   2019-10-01  [[PF emite certidão à Justiça para dizer que L...
# 1   2019-10-02  [[Para Maia, derrota em abono não significa pe...
# 2   2019-10-03  [[Flávia Boggio | Acho impossível esconder a i...
# 3   2019-10-04  [[Camargo processa ex-executivo por desvio mil...
# 4   2019-10-05  [[Desde janeiro, o jornal tem uma editoria de ...
# 5   2019-10-06  [[Em sintonia, a brasileira O Terno e a portug...
# 6   2019-10-07  [[CNN rejeita dois anúncios da campanha de Tru...
# 7   2019-10-08  [[Economia mundial sofre com desaceleração sin...
# 8   2019-10-09  [[Twitter diz que dados destinados a segurança...
# 9   2019-10-10  [[EUA detêm britânicos do Estado islâmico que ...
# 10  2019-10-11  [[HUMOR: Homenagem ao Laranja (via @ terra30)h...
# 11  2019-10-12  [[Em 'Segunda Chamada', Hermila Guedes revive ...
# 12  2019-10-13  [[Atrito Macron-Bolsonaro não afeta acordo Mer...
# 14  2019-10-15  [[Decreto do governo regulamenta trabalho temp...
# 15  2019-10-16  [[Por que se fala tanto em nova direita? O que...
# 16  2019-10-17  [[Mais jovem executivo campeão brasileiro come...
# 17  2019-10-18  [[Na contramão de Doria, gestão Covas turbina ...
# 18  2019-10-19  [[Apesar de lei, combate ao bullying segue com...
# 19  2019-10-20  [[Elio Gaspari | General Villas Bôas deveria d...
# 20  2019-10-21  [[Sylvia Colombo | O Chile é o país mais desig...
# 21  2019-10-22  [[Vereadores querem interditar aeroporto de Gu...
# 22  2019-10-23  [[Casa de Edemar Cid Ferreira, do falido Banco...
# 23  2019-10-24  [[Mundo, Universo, Terra, Grand... É possível ...
# 24  2019-10-25  [[Palestrante, Kaká fala sobre fracasso em Cop...
# 25  2019-10-26  [[Folha Top of Mind chega à 29ª edição com núm...
# 26  2019-10-27  [[Dona da Louis Vuitton faz oferta para compra...
# 27  2019-10-28  [[PVC | Contraponto é decidir que só os técnic...
# 28  2019-10-29  [[STJ aceita pedido de Lula e suspende julgame...
#
#                                          polarity_new  \
# 0   (162, Neutro, [Neutro, Neutro, Neutro, Neutro,...
# 1   (157, Neutro, [Neutro, Neutro, Neutro, Negativ...
# 2   (164, Neutro, [Neutro, Neutro, Neutro, Negativ...
# 3   (164, Neutro, [Positivo, Neutro, Neutro, Neutr...
# 4   (133, Neutro, [Neutro, Neutro, Neutro, Neutro,...
# 5   (123, Neutro, [Neutro, Neutro, Neutro, Neutro,...
# 6   (152, Neutro, [Neutro, Negativo, Neutro, Neutr...
# 7   (169, Neutro, [Neutro, Neutro, Neutro, Neutro,...
# 8   (162, Neutro, [Neutro, Neutro, Neutro, Negativ...
# 9   (167, Neutro, [Neutro, Neutro, Neutro, Neutro,...
# 10  (161, Neutro, [Neutro, Neutro, Positivo, Negat...
# 11  (131, Neutro, [Positivo, Neutro, Neutro, Posit...
# 12  (116, Neutro, [Neutro, Neutro, Neutro, Negativ...
# 14  (173, Neutro, [Negativo, Neutro, Negativo, Neg...
# 15  (166, Neutro, [Neutro, Neutro, Neutro, Neutro,...
# 16  (206, Neutro, [Positivo, Neutro, Negativo, Neu...
# 17  (167, Neutro, [Neutro, Neutro, Negativo, Posit...
# 18  (136, Neutro, [Neutro, Neutro, Negativo, Neutr...
# 19  (122, Neutro, [Neutro, Neutro, Neutro, Positiv...
# 20  (178, Neutro, [Neutro, Neutro, Neutro, Neutro,...
# 21  (180, Neutro, [Neutro, Neutro, Positivo, Negat...
# 22  (174, Neutro, [Neutro, Neutro, Positivo, Posit...
# 23  (188, Neutro, [Neutro, Neutro, Neutro, Neutro,...
# 24  (173, Neutro, [Negativo, Positivo, Neutro, Neu...
# 25  (134, Neutro, [Neutro, Neutro, Neutro, Positiv...
# 26  (139, Neutro, [Neutro, Neutro, Positivo, Neutr...
# 27  (149, Neutro, [Negativo, Neutro, Neutro, Neutr...
# 28  (139, Neutro, [Neutro, Neutro, Neutro, Positiv...
#
#                news_keywords  \
# 0               (lava, jato)
# 1     (reforma, previdência)
# 2        (pacote, anticrime)
# 3               (lava, jato)
# 4     (conselhos, tutelares)
# 5          (marcelo, álvaro)
# 6            (laranjas, psl)
# 7               (lava, jato)
# 8               (lava, jato)
# 9              (irmã, dulce)
# 10               (pode, ser)
# 11        (deputada, eleita)
# 12             (fez, piadas)
# 14      (megaleilão, présal)
# 15           (2ª, instância)
# 16       (água, contaminada)
# 17  (ranking, universitário)
# 18              (cpmi, fake)
# 19            (casé, retoma)
# 20              (lava, jato)
# 21    (reforma, previdência)
# 22                (bom, pra)
# 23             (rosa, weber)
# 24      (segunda, instância)
# 25         (américa, latina)
# 26             (domingo, 27)
# 27   (inscrições, gratuitas)
# 28          (sítio, atibaia)
#
#                                                tweets  \
# 0   1399    Lava Jato cobra multa de R$ 5 milhões ...
# 1   1398    Economia com reforma da Previdência de...
# 2   1399    Governo Federal lança campanha publici...
# 3   1399    # BRASIL: Los fiscales justicieros del...
# 4   1399    Invasão da Universal ameaça aparelhar ...
# 5   1339    Um depoimento dado à Polícia Federal e...
# 6   1388    Moro não enxerga laranjas do PSL porqu...
# 7   1399    Quer dizer que o Ministro do TCU foi A...
# 8   1399    Ministro do TCU que mandou suspender p...
# 9   1395    Mais um milagre de Irmã Dulce https://...
# 10  687    O shipp pode ser Expulsos ou Infiéis. M...
# 11  1382    AE não sei mas DE Sophia questiona a j...
# 12  1358    o jisung também fez várias piadas de p...
# 14  106    A verdadeira explicação para o golpe de...
# 15  697    ESTÃO ABORRECIDOS?!?!?!?!? VCS AINDA NÃ...
# 16  1209    Você bebe agrotóxicos? Descubra se a á...
# 17  1347    Quer estudar em uma universidade inova...
# 18  424    É SURREAL! 1º a senadora fala q assinou...
# 19  850    Regina Casé retoma seu lado atriz em fi...
# 20  1398    Em 7 minutos, advogado dá aula de étic...
# 21  1399    Reforma da previdência passou !!! Bras...
# 22  692    1. Converse com suas amigas sobre, ajud...
# 23  1399    Rosa Weber é uma Vaca. Retwitem até vi...
# 24  1397              Queremos prisão após segunda...
# 25  1399    América Latina NUNCA MAIS o Neoliberal...
# 26  468    Con el 71,27% de las mesas escrutadas, ...
# 27  1266    Gratuitas, estão abertas as inscrições...
# 28  1397    E também do sítio em Atibaia e o tripl...
#
#                                     normalized_tweets  \
# 0   1399    [lava, jato, cobra, multa, de, r, 5, m...
# 1   1398    [economia, com, reforma, da, previdênc...
# 2   1399    [governo, federal, lança, campanha, pu...
# 3   1399    [brasil, los, fiscales, justicieros, d...
# 4   1399    [invasão, da, universal, ameaça, apare...
# 5   1339    [um, depoimento, dado, à, polícia, fed...
# 6   1388    [moro, não, enxerga, laranjas, do, psl...
# 7   1399    [quer, dizer, que, o, ministro, do, tc...
# 8   1399    [ministro, do, tcu, que, mandou, suspe...
# 9   1395                 [mais, um, milagre, de, i...
# 10  687    [o, ship, pode, ser, expulsos, ou, infi...
# 11  1382    [ae, não, sei, mas, de, sophia, questi...
# 12  1358    [o, jisung, também, fez, várias, piada...
# 14  106    [a, verdadeira, explicação, para, o, go...
# 15  697    [estão, aborecidos, vcs, ainda, não, vi...
# 16  1209    [você, bebe, agrotóxicos, descubra, se...
# 17  1347    [quer, estudar, em, uma, universidade,...
# 18  424    [é, sureal, 1º, a, senadora, fala, q, a...
# 19  850    [regina, casé, retoma, seu, lado, atriz...
# 20  1398    [em, 7, minutos, advogado, dá, aula, d...
# 21  1399    [reforma, da, previdência, passou, bra...
# 22  692    [1, converse, com, suas, amigas, sobre,...
# 23  1399    [rosa, weber, é, uma, vaca, retwitem, ...
# 24  1397         [queremos, prisão, após, segunda,...
# 25  1399    [américa, latina, nunca, mais, o, neol...
# 26  468    [con, el, 7127, de, las, mesas, escruta...
# 27  1266    [gratuitas, estão, abertas, as, inscri...
# 28  1397    [e, também, do, sítio, em, atibaia, e,...
#
#                                       polarity_tweets
# 0   (484, Neutro, [Negativo, Neutro, Neutro, Negat...
# 1   (394, Neutro, [Neutro, Neutro, Neutro, Neutro,...
# 2   (634, Neutro, [Neutro, Neutro, Neutro, Positiv...
# 3   (463, Neutro, [Neutro, Neutro, Neutro, Neutro,...
# 4   (422, Neutro, [Neutro, Neutro, Neutro, Neutro,...
# 5   (9, Neutro, [Positivo, Neutro, Negativo, Neutr...
# 6   (79, Neutro, [Neutro, Neutro, Neutro, Neutro, ...
# 7   (450, Neutro, [Neutro, Neutro, Negativo, Neutr...
# 8   (475, Neutro, [Neutro, Neutro, Neutro, Neutro,...
# 9   (120, Neutro, [Positivo, Neutro, Positivo, Neu...
# 10  (133, Neutro, [Neutro, Negativo, Neutro, Neutr...
# 11  (55, Neutro, [Negativo, Neutro, Neutro, Neutro...
# 12  (13, Neutro, [Neutro, Neutro, Neutro, Neutro, ...
# 14  (54, Neutro, [Neutro, Neutro, Neutro, Neutro, ...
# 15  (425, Neutro, [Negativo, Neutro, Neutro, Neutr...
# 16  (32, Neutro, [Negativo, Neutro, Negativo, Posi...
# 17                      (2, Neutro, [Neutro, Neutro])
# 18  (285, Neutro, [Neutro, Neutro, Positivo, Neutr...
# 19  (9, Neutro, [Neutro, Positivo, Neutro, Neutro,...
# 20  (466, Neutro, [Neutro, Neutro, Neutro, Neutro,...
# 21  (460, Neutro, [Neutro, Neutro, Neutro, Neutro,...
# 22  (83, Neutro, [Neutro, Positivo, Neutro, Neutro...
# 23  (496, Neutro, [Positivo, Neutro, Negativo, Neu...
# 24  (257, Neutro, [Neutro, Neutro, Neutro, Neutro,...
# 25  (407, Neutro, [Positivo, Neutro, Neutro, Neutr...
# 26  (5, Neutro, [Neutro, Neutro, Neutro, Neutro, P...
# 27  (31, Neutro, [Neutro, Positivo, Neutro, Neutro...
# 28  (554, Neutro, [Negativo, Neutro, Neutro, Neutr...

# %%
pd.DataFrame(depurate_tweets).to_pickle('../data/rated_news.pkl')
